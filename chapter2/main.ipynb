# %%
{
    "model": "gpt-4o-mini",
    "messages": [
        {"role": "system", "content": "You are helpful assistant."},
        {"role": "user", "content": "こんにちは！私は賢二と言います！"},
        {"role": "assistant", "content": "こんにちは、賢二さん！お会いできて嬉しいです。今日はどんなことをお話ししましょうか？"},
        {"role": "user", "content": "私の名前がわかりますか？"}
    ]
}
# Out:
# {'model': 'gpt-4o-mini',
#  'messages': [{'role': 'system', 'content': 'You are helpful assistant.'},
#   {'role': 'user', 'content': 'こんにちは！私は賢二と言います！'},
#   {'role': 'assistant',
#    'content': 'こんにちは、賢二さん！お会いできて嬉しいです。今日はどんなことをお話ししましょうか？'},
#   {'role': 'user', 'content': '私の名前がわかりますか？'}]}

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# override=True を追加して、強制的に .env の内容で上書きします
load_dotenv(override=True)

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are helpful assistant."},
        {"role": "user", "content": "こんにちは！私は賢二と言います！"},
    ]
)
print(response.to_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-DLOa6XBRhw4pvVVcCVFELm7QyHWlY",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "こんにちは、賢二さん！お会いできて嬉しいです。今日は何か特別なことをお話ししたいですか？",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": []
#       }
#     }
#   ],
#   "created": 1773991750,
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_ca3e7d71bf",
#   "usage": {
#     "completion_tokens": 32,
#     "prompt_tokens": 25,
#     "total_tokens": 57,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are helpful assistant."},
        {"role": "user", "content": "こんにちは！私は賢二と言います!"},
        {"role": "assistant", "content": "こんにちは、賢二さん！お会いできて嬉しいです。今日はどんなことをお話ししましょうか？"},
        {"role": "user", "content": "私の名前がわかりますか？"},
    ],
)
print(response.to_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-DLOfRd4kNKSyNNweQEKkBYrDZfUw0",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "はい、賢二さんですね。何か特別なことについてお話ししたいことがありますか？",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": []
#       }
#     }
#   ],
#   "created": 1773992081,
#   "model": "gpt-4o-mini-2024-07-18",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_03e549354a",
#   "usage": {
#     "completion_tokens": 24,
#     "prompt_tokens": 70,
#     "total_tokens": 94,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are helpful assistant."},
        {"role": "user", "content": "こんにちは！私は賢二と言います！"},
    ],
    stream=True,
)

for chunk in response:
    content = chunk.choices[0].delta.content
    if content is not None:
        print(content, end="", flush=True)
# Out:
# こんにちは、賢二さん！お会いできて嬉しいです。今日はどんなことをお話ししましょうか？

# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "system",
            "content": '人物一覧をJSON形式で出力してください。\n{"people":["aaa", "bbb"]}',
        },
        {
            "role": "user",
            "content": "昔々あるところに大お爺さんと大お婆さんがいました。",
        },
    ],
    response_format={"type": "json_object"},
)
print(response.choices[0].message.content)
# Out:
# {"people":["大お爺さん", "大お婆さん"]}

# %%
import json

def get_current_weather(location, unit="fahrenfeit"):
    if "tokyo" in location.lower():
        return json.dumps({"location": "Tokyo", "temperature": "10", "unit": unit})
    elif "san francisco" in location.lower():
        return json.dumps({"location": "San Francisco", "temperature": "72", "unit": unit})
    elif "paris" in location.lower():
        return json.dumps({"location": "Paris", "temperature": "22", "unit": unit}),
    else:
        return json.dumps({"location": location, "temperature": "unknown"})

# %%
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_current_weather",
            "description": "Get the current weather in a given location",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g.san Francisco, CA",
                    },
                    "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]},
                },
                "required": ["location"],
            },
        }
    }
]

# %%
from openai import OpenAI

client = OpenAI()

messages = [
    {"role": "user", "content": "東京の天気はどうですか？"},
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages,
    tools=tools,
)
print(response.to_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-DLP8uQh9cH8vcA9GgYAwxN1mn3vEK",
#   "choices": [
#     {
#       "finish_reason": "tool_calls",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": null,
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "tool_calls": [
#           {
#             "id": "call_fjb6q58akEKgklfxvsjIYl75",
#             "function": {
#               "arguments": "{\"location\":\"Tokyo, Japan\"}",
#               "name": "get_current_weather"
#             },
#             "type": "function"
#           }
#         ]
#       }
#     }
#   ],
#   "created": 1773993908,
#   "model": "gpt-4o-2024-08-06",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_3e502a9bb4",
#   "usage": {
#     "completion_tokens": 17,
#     "prompt_tokens": 81,
#     "total_tokens": 98,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
# ...

# %%
response_message = response.choices[0].message
messages.append(response_message.to_dict())

# %%
available_functions = {
    "get_current_weather": get_current_weather,
}

for tool_call in response_message.tool_calls:
    function_name = tool_call.function.name
    function_to_call = available_functions[function_name]
    function_args = json.loads(tool_call.function.arguments)
    function_response = function_to_call(
        location=function_args.get("location"),
        unit=function_args.get("unit"),
    )

    messages.append(
        {
            "tool_call_id": tool_call.id,
            "role": "tool",
            "name": function_name,
            "content": function_response,
        }
    )

# %%
print(json.dumps(messages, ensure_ascii=False, indent=2))
# Out:
# [
#   {
#     "role": "user",
#     "content": "東京の天気はどうですか？"
#   },
#   {
#     "content": null,
#     "refusal": null,
#     "role": "assistant",
#     "annotations": [],
#     "tool_calls": [
#       {
#         "id": "call_fjb6q58akEKgklfxvsjIYl75",
#         "function": {
#           "arguments": "{\"location\":\"Tokyo, Japan\"}",
#           "name": "get_current_weather"
#         },
#         "type": "function"
#       }
#     ]
#   },
#   {
#     "tool_call_id": "call_fjb6q58akEKgklfxvsjIYl75",
#     "role": "tool",
#     "name": "get_current_weather",
#     "content": "{\"location\": \"Tokyo\", \"temperature\": \"10\", \"unit\": null}"
#   }
# ]

# %%
second_response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages,
)
print(second_response.to_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-DLPTUW3BBp5qyxNioQQa9idc8VrOt",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "東京の現在の気温は10度です。使用している天気データソースによって詳細情報が不足している可能性がありますが、他に知りたい情報があれば教えてください。",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": []
#       }
#     }
#   ],
#   "created": 1773995184,
#   "model": "gpt-4o-2024-08-06",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_302b87bc9f",
#   "usage": {
#     "completion_tokens": 46,
#     "prompt_tokens": 59,
#     "total_tokens": 105,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }
